# %% [markdown]
# # Gathering the necessary data, put into a dataframe, and then output as csv files.

# %%
# Necessary import:
from selenium import webdriver
from selenium.webdriver.edge.service import Service as EdgeService
from selenium.webdriver.common.by import By
from webdriver_manager.microsoft import EdgeChromiumDriverManager
import time
import pandas as pd
import re

# %% [markdown]
# ## Scraping the results using Selenium:

# %% [markdown]
# ### Declaring a function first that will be used to get the "Results" from the tables gathered by the Selenium:

# %%
def result_scraper_selenium(table: list) -> list:
    """This function scrapes the cells with color in each raw table.

    Args:
        table (list): A list containing raw tables.

    Returns:
        list: A list consisting of cells with color in it.
    """
    data_table_selenium = []

    for per_table in table:
        rows = per_table.find_elements(By.TAG_NAME, "tr")
        for per_row in rows:
            cells = per_row.find_elements(By.TAG_NAME, "td")
            for per_cell in cells:
                attri_value = per_cell.get_attribute("style")
                data_table_selenium.append(attri_value)
    
    return data_table_selenium

# %% [markdown]
# ### Part 1 - Scraped all the necessary tables:

# %%
driver = webdriver.Edge(service=EdgeService(EdgeChromiumDriverManager().install()))

page_url = "https://en.wikipedia.org/wiki/List_of_DoReMi_Market_episodes"

driver.get(page_url)
# Wait for 3 seconds to make sure that the webpage has been load properly.
time.sleep(3)

all_tables_selenium = driver.find_elements(by="xpath", value="//div[contains(@class, \"hidden-content mw-collapsible-content\")]")
# This function get color values from td tag of the HTML:
data_table_selenium = result_scraper_selenium(all_tables_selenium)

driver.quit()

# %%
# Looking at the "data_table_selenium":
print(f"Number of rows: {len(data_table_selenium)}\n")
data_table_selenium
# Out:
# Number of rows: 1841
# ['',
#  '',
#  'background: rgb(174, 214, 241);',
#  'background: rgb(236, 236, 236); color: rgb(44, 44, 44); vertical-align: middle; text-align: center;',
#  'background: rgb(230, 176, 170);',
#  'background: rgb(230, 176, 170);',
#  '',
#  'background: rgb(230, 176, 170);',
#  'background: rgb(174, 214, 241);',
#  'background: rgb(230, 176, 170);',
#  '',
#  '',
#  'background: rgb(230, 176, 170);',
#  'background: rgb(174, 214, 241);',
#  'background: rgb(230, 176, 170);',
#  '',
#  '',
#  'background: rgb(230, 176, 170);',
#  'background: rgb(230, 176, 170);',
#  'background: rgb(210, 180, 222);',
#  '',
#  '',
#  'background: rgb(210, 180, 222);',
#  '',
#  'background: rgb(210, 180, 222);',
#  '',
#  '',
#  'background: rgb(174, 214, 241);',
#  '',
#  'background: rgb(174, 214, 241);',
#  '',
#  '',
#  'background: rgb(210, 180, 222);',
#  '',
#  'background: rgb(174, 214, 241);',
#  '',
#  '',
#  'background: rgb(174, 214, 241);',
#  '',
#  '',
#  'background: rgb(174, 214, 241);',
#  '',
#  '',
#  'background: rgb(210, 180, 222);',
#  '',
#  '',
#  'background: rgb(210, 180, 222);',
#  '',
#  '',
#  'background: rgb(174, 214, 241);',
#  '',
#  '',
#  'background: rgb(210, 180, 222);',
#  '',
#  '',
#  'background: rgb(174, 214, 241);',
#  '',
#  '',
#  'background: rgb(210, 180, 222);',
#  '',
#  '',
#  'background: rgb(174, 214, 241);',
#  '',
#  '',
#  'background: rgb(171, 235, 198);',
#  '',
#  '',
#  'background: rgb(230, 176, 170);',
#  '',
#  '',
#  'background: rgb(174, 214, 241);',
#  '',
#  '',
#  'background: rgb(171, 235, 198);',
#  '',
#  '',
#  'background: rgb(171, 235, 198);',
#  '',
#  '',
#  'background: rgb(230, 176, 170);',
#  '',
#  '',
#  'background: rgb(171, 235, 198);',
#  '',
#  '',
#  'background: rgb(210, 180, 222);',
#  '',
#  '',
#  'background: rgb(171, 235, 198);',
#  '',
#  '',
#  'background: rgb(174, 214, 241);',
#  '',
#  '',
#  'background: rgb(210, 180, 222);',
#  '',
#  '',
#  'background: rgb(174, 214, 241);',
#  '',
#  '',
#  'background: rgb(210, 180, 222);',
#  '',
#  '',
#  'background: rgb(174, 214, 241);',
#  '',
#  '',
#  'background: rgb(210, 180, 222);',
#  '',
#  '',
#  'background: rgb(174, 214, 241);',
#  '',
#  '',
#  'background: rgb(171, 235, 198);',
#  '',
#  '',
#  'background: rgb(174, 214, 241);',
#  '',
#  '',
#  'background: rgb(210, 180, 222);',
#  '',
#  '',
#  'background: rgb(210, 180, 222);',
#  '',
#  '',
#  'background: rgb(174, 214, 241);',
#  '',
#  '',
#  'background: rgb(210, 180, 222);',
#  '',
#  '',
#  'background: rgb(210, 180, 222);',
#  '',
#  '',
#  'background: rgb(171, 235, 198);',
#  '',
#  '',
#  'background: rgb(210, 180, 222);',
#  '',
#  '',
#  'background: rgb(210, 180, 222);',
#  '',
#  '',
#  'background: rgb(210, 180, 222);',
#  '',
#  '',
#  'background: rgb(171, 235, 198);',
#  '',
#  '',
#  'background: rgb(210, 180, 222);',
#  '',
#  '',
#  'background: rgb(174, 214, 241);',
#  '',
#  '',
#  'background: rgb(174, 214, 241);',
#  '',
#  '',
#  'background: rgb(210, 180, 222);',
#  '',
#  '',
#  'background: rgb(174, 214, 241);',
#  '',
#  '',
#  'background: rgb(171, 235, 198);',
#  '',
#  '',
#  'background: rgb(230, 176, 170);',
#  '',
#  '',
#  'background: rgb(174, 214, 241);',
#  '',
#  '',
#  'background: rgb(171, 235, 198);',
#  '',
#  '',
#  'background: rgb(230, 176, 170);',
#  '',
#  '',
#  'background: rgb(174, 214, 241);',
#  '',
#  '',
#  'background: rgb(174, 214, 241);',
#  '',
#  '',
#  'background: rgb(174, 214, 241);',
#  '',
#  '',
#  'background: rgb(174, 214, 241);',
#  '',
#  '',
#  'background: rgb(210, 180, 222);',
#  '',
#  '',
#  'background: rgb(210, 180, 222);',
#  '',
#  '',
#  'background: rgb(210, 180, 222);',
#  '',
#  '',
#  'background: rgb(230, 176, 170);',
#  '',
#  '',
#  'background: rgb(171, 235, 198);',
#  '',
#  '',
#  'background: rgb(174, 214, 241);',
#  '',
#  '',
#  'background: rgb(174, 214, 241);',
#  '',
#  '',
#  'background: rgb(174, 214, 241);',
#  '',
#  '',
#  'background: rgb(174, 214, 241);',
#  '',
#  '',
#  'background: rgb(210, 180, 222);',
#  '',
#  '',
#  'background: rgb(174, 214, 241);',
#  '',
#  '',
#  'background: rgb(210, 180, 222);',
#  '',
#  '',
#  'background: rgb(174, 214, 241);',
#  '',
#  '',
#  'background: rgb(174, 214, 241);',
#  '',
#  '',
#  'background: rgb(174, 214, 241);',
#  '',
#  '',
#  'background: rgb(171, 235, 198);',
#  '',
#  '',
#  'background: rgb(171, 235, 198);',
#  '',
#  '',
#  'background: rgb(174, 214, 241);',
#  '',
#  '',
#  'background: rgb(210, 180, 222);',
#  '',
#  '',
#  'background: rgb(174, 214, 241);',
#  '',
#  '',
#  'background: rgb(171, 235, 198);',
#  '',
#  '',
#  'background: rgb(210, 180, 222);',
#  '',
#  '',
#  'background: rgb(174, 214, 241);',
#  '',
#  '',
#  'background: rgb(210, 180, 222);',
#  '',
#  '',
#  'background: rgb(171, 235, 198);',
#  '',
#  '',
#  'background: rgb(174, 214, 241);',
#  '',
#  '',
#  'background: rgb(210, 180, 222);',
#  '',
#  '',
#  'background: rgb(210, 180, 222);',
#  '',
#  '',
#  'background: rgb(174, 214, 241);',
#  '',
#  '',
#  'background: rgb(210, 180, 222);',
#  '',
#  '',
#  'background: rgb(174, 214, 241);',
#  '',
#  '',
#  'background: rgb(174, 214, 241);',
#  '',
#  '',
#  'background: rgb(210, 180, 222);',
#  '',
#  '',
#  'background: rgb(174, 214, 241);',
#  '',
#  '',
#  'background: rgb(174, 214, 241);',
#  '',
#  '',
#  'background: rgb(174, 214, 241);',
#  '',
#  '',
#  'background: rgb(174, 214, 241);',
#  '',
#  '',
#  'background: rgb(174, 214, 241);',
#  '',
#  '',
#  'background: rgb(171, 235, 198);',
#  '',
#  '',
#  'background: rgb(174, 214, 241);',
#  '',
#  '',
#  'background: rgb(174, 214, 241);',
#  '',
#  '',
#  'background: rgb(210, 180, 222);',
#  '',
#  '',
#  'background: rgb(174, 214, 241);',
#  '',
#  '',
#  'background: rgb(230, 176, 170);',
#  '',
#  '',
#  'background: rgb(171, 235, 198);',
#  '',
#  '',
#  'background: rgb(174, 214, 241);',
#  '',
#  '',
#  'background: rgb(171, 235, 198);',
#  '',
#  '',
#  'background: rgb(210, 180, 222);',
#  '',
#  '',
#  'background: rgb(210, 180, 222);',
#  '',
#  '',
#  'background: rgb(174, 214, 241);',
#  '',
#  '',
#  'background: rgb(174, 214, 241);',
#  '',
#  '',
#  'background: rgb(230, 176, 170);',
#  '',
#  '',
#  'background: rgb(174, 214, 241);',
#  '',
#  '',
#  'background: rgb(230, 176, 170);',
#  '',
#  '',
#  'background: rgb(174, 214, 241);',
#  '',
#  '',
#  'background: rgb(210, 180, 222);',
#  '',
#  '',
#  'background: rgb(171, 235, 198);',
#  '',
#  '',
#  'background: rgb(174, 214, 241);',
#  '',
#  '',
#  'background: rgb(174, 214, 241);',
#  '',
#  '',
#  'background: rgb(210, 180, 222);',
#  '',
#  '',
#  'background: rgb(174, 214, 241);',
#  '',
#  '',
#  'background: rgb(210, 180, 222);',
#  '',
#  '',
#  'background: rgb(174, 214, 241);',
#  '',
#  '',
#  'background: rgb(174, 214, 241);',
#  '',
#  '',
#  'background: rgb(210, 180, 222);',
#  '',
#  '',
#  'background: rgb(174, 214, 241);',
#  '',
#  '',
#  'background: rgb(210, 180, 222);',
#  '',
#  '',
#  'background: rgb(174, 214, 241);',
#  '',
#  '',
#  'background: rgb(171, 235, 198);',
#  '',
#  '',
#  'background: rgb(210, 180, 222);',
#  '',
#  '',
#  'background: rgb(230, 176, 170);',
#  '',
#  '',
#  'background: rgb(171, 235, 198);',
#  '',
#  '',
#  'background: rgb(210, 180, 222);',
#  '',
#  '',
#  'background: rgb(171, 235, 198);',
#  '',
#  '',
#  'background: rgb(230, 176, 170);',
#  '',
#  '',
#  'background: rgb(174, 214, 241);',
#  '',
#  '',
#  'background: rgb(171, 235, 198);',
#  '',
#  '',
#  'background: rgb(210, 180, 222);',
#  '',
#  '',
#  'background: rgb(174, 214, 241);',
#  '',
#  '',
#  'background: rgb(174, 214, 241);',
#  '',
#  '',
#  'background: rgb(171, 235, 198);',
#  '',
#  '',
#  'background: rgb(174, 214, 241);',
#  '',
#  '',
#  'background: rgb(171, 235, 198);',
#  '',
#  '',
#  'background: rgb(210, 180, 222);',
#  '',
#  '',
#  'background: rgb(174, 214, 241);',
#  '',
#  'background: rgb(236, 236, 236); color: rgb(44, 44, 44); vertical-align: middle; text-align: center;',
#  '',
#  '',
#  'background: rgb(174, 214, 241);',
#  '',
#  '',
#  'background: rgb(174, 214, 241);',
#  '',
#  '',
#  'background: rgb(210, 180, 222);',
#  '',
#  '',
#  'background: rgb(210, 180, 222);',
#  '',
#  '',
#  'background: rgb(174, 214, 241);',
#  '',
#  '',
#  'background: rgb(210, 180, 222);',
#  '',
#  '',
#  'background: rgb(174, 214, 241);',
#  '',
#  '',
#  'background: rgb(174, 214, 241);',
#  '',
#  '',
#  'background: rgb(174, 214, 241);',
#  '',
#  '',
#  'background: rgb(174, 214, 241);',
#  '',
#  '',
#  'background: rgb(174, 214, 241);',
#  '',
#  '',
#  'background: rgb(174, 214, 241);',
#  '',
#  '',
#  'background: rgb(210, 180, 222);',
#  '',
#  '',
#  'background: rgb(174, 214, 241);',
#  '',
#  'background: rgb(236, 236, 236); color: rgb(44, 44, 44); vertical-align: middle; text-align: center;',
#  '',
#  '',
#  'background: rgb(174, 214, 241);',
#  '',
#  '',
#  'background: rgb(210, 180, 222);',
#  '',
#  '',
#  'background: rgb(174, 214, 241);',
#  '',
#  '',
#  'background: rgb(230, 176, 170);',
#  '',
#  '',
#  'background: rgb(174, 214, 241);',
#  '',
#  '',
#  'background: rgb(210, 180, 222);',
#  '',
#  '',
#  'background: rgb(174, 214, 241);',
#  '',
#  '',
#  'background: rgb(171, 235, 198);',
#  '',
#  '',
#  'background: rgb(210, 180, 222);',
#  '',
#  '',
#  'background: rgb(210, 180, 222);',
#  '',
#  '',
#  'background: rgb(230, 176, 170);',
#  '',
#  '',
#  'background: rgb(171, 235, 198);',
#  '',
#  '',
#  'background: rgb(174, 214, 241);',
#  '',
#  '',
#  'background: rgb(210, 180, 222);',
#  '',
#  '',
#  'background: rgb(230, 176, 170);',
#  '',
#  '',
#  'background: rgb(171, 235, 198);',
#  '',
#  '',
#  'background: rgb(174, 214, 241);',
#  '',
#  '',
#  'background: rgb(174, 214, 241);',
#  '',
#  '',
#  'background: rgb(174, 214, 241);',
#  '',
#  '',
#  'background: rgb(174, 214, 241);',
#  '',
#  '',
#  'background: rgb(210, 180, 222);',
#  '',
#  '',
#  'background: rgb(171, 235, 198);',
#  '',
#  '',
#  'background: rgb(210, 180, 222);',
#  '',
#  '',
#  'background: rgb(174, 214, 241);',
#  '',
#  '',
#  'background: rgb(174, 214, 241);',
#  '',
#  '',
#  'background: rgb(174, 214, 241);',
#  '',
#  '',
#  'background: rgb(210, 180, 222);',
#  '',
#  '',
#  'background: rgb(174, 214, 241);',
#  '',
#  '',
#  'background: rgb(174, 214, 241);',
#  '',
#  '',
#  'background: rgb(210, 180, 222);',
#  '',
#  '',
#  'background: rgb(230, 176, 170);',
#  '',
#  '',
#  'background: rgb(171, 235, 198);',
#  '',
#  '',
#  'background: rgb(174, 214, 241);',
#  '',
#  '',
#  'background: rgb(174, 214, 241);',
#  'background: rgb(236, 236, 236); color: rgb(44, 44, 44); vertical-align: middle; text-align: center;',
#  '',
#  'background: rgb(230, 176, 170);',
#  '',
#  '',
#  'background: rgb(174, 214, 241);',
#  '',
#  '',
#  '',
#  'background: rgb(174, 214, 241);',
#  '',
#  '',
#  'background: rgb(230, 176, 170);',
#  '',
#  '',
#  'background: rgb(210, 180, 222);',
#  '',
#  '',
#  'background: rgb(210, 180, 222);',
#  '',
#  'background: rgb(236, 236, 236); color: rgb(44, 44, 44); vertical-align: middle; text-align: center;',
#  '',
#  '',
#  'background: rgb(174, 214, 241);',
#  '',
#  '',
#  'background: rgb(230, 176, 170);',
#  '',
#  '',
#  'background: rgb(171, 235, 198);',
#  '',
#  '',
#  'background: rgb(171, 235, 198);',
#  '',
#  '',
#  'background: rgb(210, 180, 222);',
#  '',
#  '',
#  'background: rgb(174, 214, 241);',
#  '',
#  '',
#  'background: rgb(174, 214, 241);',
#  '',
#  '',
#  'background: rgb(210, 180, 222);',
#  '',
#  '',
#  'background: rgb(174, 214, 241);',
#  '',
#  '',
#  'background: rgb(210, 180, 222);',
#  '',
#  '',
#  'background: rgb(171, 235, 198);',
#  '',
#  '',
#  'background: rgb(174, 214, 241);',
#  '',
#  '',
#  'background: rgb(230, 176, 170);',
#  '',
#  '',
#  'background: rgb(171, 235, 198);',
#  '',
#  '',
#  'background: rgb(210, 180, 222);',
#  '',
#  '',
#  'background: rgb(210, 180, 222);',
#  '',
#  '',
#  'background: rgb(171, 235, 198);',
#  '',
#  '',
#  'background: rgb(174, 214, 241);',
#  '',
#  '',
#  'background: rgb(174, 214, 241);',
#  '',
#  '',
#  'background: rgb(210, 180, 222);',
#  '',
#  '',
#  'background: rgb(230, 176, 170);',
#  '',
#  '',
#  'background: rgb(174, 214, 241);',
#  '',
#  '',
#  'background: rgb(210, 180, 222);',
#  '',
#  '',
#  'background: rgb(174, 214, 241);',
#  '',
#  '',
#  'background: rgb(210, 180, 222);',
#  '',
#  '',
#  'background: rgb(171, 235, 198);',
#  '',
#  '',
#  'background: rgb(174, 214, 241);',
#  '',
#  '',
#  'background: rgb(174, 214, 241);',
#  '',
#  '',
#  'background: rgb(174, 214, 241);',
#  '',
#  '',
#  'background: rgb(230, 176, 170);',
#  '',
#  '',
#  'background: rgb(174, 214, 241);',
#  '',
#  '',
#  'background: rgb(171, 235, 198);',
#  '',
#  '',
#  'background: rgb(174, 214, 241);',
#  '',
#  '',
#  'background: rgb(210, 180, 222);',
#  '',
#  '',
#  'background: rgb(230, 176, 170);',
#  '',
#  '',
#  'background: rgb(174, 214, 241);',
#  '',
#  '',
#  'background: rgb(171, 235, 198);',
#  '',
#  '',
#  'background: rgb(174, 214, 241);',
#  '',
#  '',
#  'background: rgb(171, 235, 198);',
#  '',
#  '',
#  'background: rgb(230, 176, 170);',
#  '',
#  '',
#  'background: rgb(174, 214, 241);',
#  '',
#  '',
#  'background: rgb(210, 180, 222);',
#  '',
#  '',
#  'background: rgb(174, 214, 241);',
#  '',
#  '',
#  'background: rgb(210, 180, 222);',
#  '',
#  '',
#  'background: rgb(210, 180, 222);',
#  '',
#  '',
#  'background: rgb(171, 235, 198);',
#  '',
#  '',
#  'background: rgb(174, 214, 241);',
#  '',
#  '',
#  'background: rgb(210, 180, 222);',
#  '',
#  '',
#  'background: rgb(174, 214, 241);',
#  '',
#  '',
#  'background: rgb(210, 180, 222);',
#  '',
#  '',
#  'background: rgb(174, 214, 241);',
#  '',
#  '',
#  'background: rgb(174, 214, 241);',
#  '',
#  '',
#  'background: rgb(230, 176, 170);',
#  '',
#  '',
#  'background: rgb(174, 214, 241);',
#  '',
#  '',
#  'background: rgb(174, 214, 241);',
#  '',
#  '',
#  'background: rgb(174, 214, 241);',
#  '',
#  '',
#  'background: rgb(174, 214, 241);',
#  '',
#  '',
#  'background: rgb(230, 176, 170);',
#  '',
#  '',
#  'background: rgb(174, 214, 241);',
#  '',
#  '',
#  'background: rgb(210, 180, 222);',
#  '',
#  '',
#  'background: rgb(174, 214, 241);',
#  '',
#  '',
#  'background: rgb(171, 235, 198);',
#  '',
#  '',
#  'background: rgb(174, 214, 241);',
#  'background: rgb(236, 236, 236); color: rgb(44, 44, 44); vertical-align: middle; text-align: center;',
#  '',
#  'background: rgb(174, 214, 241);',
#  '',
#  '',
#  'background: rgb(210, 180, 222);',
#  '',
#  '',
#  'background: rgb(174, 214, 241);',
#  '',
#  '',
#  'background: rgb(174, 214, 241);',
#  '',
#  '',
#  'background: rgb(171, 235, 198);',
#  '',
#  '',
#  'background: rgb(171, 235, 198);',
#  '',
#  '',
#  'background: rgb(174, 214, 241);',
#  '',
#  '',
#  'background: rgb(174, 214, 241);',
#  '',
#  '',
#  'background: rgb(230, 176, 170);',
#  '',
#  '',
#  'background: rgb(210, 180, 222);',
#  '',
#  '',
#  'background: rgb(174, 214, 241);',
#  '',
#  '',
#  'background: rgb(210, 180, 222);',
#  '',
#  '',
#  'background: rgb(174, 214, 241);',
#  '',
#  '',
#  'background: rgb(230, 176, 170);',
#  '',
#  '',
#  'background: rgb(210, 180, 222);',
#  '',
#  '',
#  'background: rgb(174, 214, 241);',
#  '',
#  '',
#  'background: rgb(171, 235, 198);',
#  '',
#  '',
#  'background: rgb(210, 180, 222);',
#  '',
#  '',
#  'background: rgb(171, 235, 198);',
#  '',
#  '',
#  'background: rgb(171, 235, 198);',
#  '',
#  '',
#  'background: rgb(210, 180, 222);',
#  '',
#  '',
#  'background: rgb(174, 214, 241);',
#  '',
#  '',
#  'background: rgb(174, 214, 241);',
#  '',
#  '',
#  'background: rgb(174, 214, 241);',
#  '',
#  '',
#  'background: rgb(236, 236, 236); color: rgb(44, 44, 44); vertical-align: middle; text-align: center;',
#  '',
#  '',
#  'background: rgb(174, 214, 241);',
#  '',
#  '',
#  'background: rgb(174, 214, 241);',
#  '',
#  '',
#  'background: rgb(174, 214, 241);',
#  '',
#  '',
#  'background: rgb(171, 235, 198);',
#  '',
#  '',
#  'background: rgb(174, 214, 241);',
#  '',
#  '',
#  'background: rgb(171, 235, 198);',
#  '',
#  '',
#  'background: rgb(210, 180, 222);',
#  '',
#  '',
#  'background: rgb(171, 235, 198);',
#  '',
#  '',
#  'background: rgb(174, 214, 241);',
#  '',
#  '',
#  'background: rgb(174, 214, 241);',
#  '',
#  '',
#  'background: rgb(230, 176, 170);',
#  '',
#  '',
#  'background: rgb(171, 235, 198);',
#  '',
#  '',
#  'background: rgb(171, 235, 198);',
#  '',
#  '',
#  'background: rgb(210, 180, 222);',
#  '',
#  '',
#  'background: rgb(171, 235, 198);',
#  '',
#  '',
#  'background: rgb(171, 235, 198);',
#  '',
#  '',
#  'background: rgb(171, 235, 198);',
#  '',
#  '',
#  'background: rgb(174, 214, 241);',
#  '',
#  '',
#  'background: rgb(171, 235, 198);',
#  '',
#  '',
#  'background: rgb(174, 214, 241);',
#  '',
#  '',
#  'background: rgb(171, 235, 198);',
#  '',
#  '',
#  'background: rgb(171, 235, 198);',
#  '',
#  '',
#  'background: rgb(210, 180, 222);',
#  '',
#  '',
#  'background: rgb(174, 214, 241);',
#  '',
#  '',
#  'background: rgb(174, 214, 241);',
#  '',
#  '',
#  'background: rgb(230, 176, 170);',
#  '',
#  '',
#  'background: rgb(174, 214, 241);',
#  '',
#  '',
#  'background: rgb(171, 235, 198);',
#  '',
#  '',
#  'background: rgb(174, 214, 241);',
#  '',
#  '',
#  'background: rgb(174, 214, 241);',
#  '',
#  '',
#  'background: rgb(171, 235, 198);',
#  '',
#  '',
#  'background: rgb(174, 214, 241);',
#  '',
#  '',
#  'background: rgb(174, 214, 241);',
#  '',
#  '',
#  'background: rgb(174, 214, 241);',
#  '',
#  '',
#  'background: rgb(174, 214, 241);',
#  '',
#  '',
#  'background: rgb(174, 214, 241);',
#  '',
#  '',
#  'background: rgb(171, 235, 198);',
#  '',
#  '',
#  'background: rgb(171, 235, 198);',
#  '',
#  '',
#  'background: rgb(174, 214, 241);',
#  '',
#  '',
#  'background: rgb(174, 214, 241);',
#  '',
#  '',
#  'background: rgb(174, 214, 241);',
#  '',
#  ...]

# %% [markdown]
# ### With this, we can see that there's a lot of data outliers. This need to be fix. Will be declaring a function again to cleaned the data:

# %% [markdown]
# ### Part 2 - Cleaning the data gathered using Selenium:

# %%
# This will use as a pattern for the function to be declared:
'''
                        RGB Values:
Success - 1st attempt - 171, 235, 198   -   Green   -   "background: rgb(171, 235, 198);    -   #ABEBC6"
Success - 2nd attempt - 174, 214, 241   -   Blue    -   "background: rgb(174, 214, 241);    -   #AED6F1"
Success - 3rd attempt - 230, 176, 170   -   Red     -   "background: rgb(230, 176, 170);    -   #E6B0AA"
Failed                - 210, 180, 222   -   Purple  -   "background: rgb(210, 180, 222);    -   #D2B4DE"
'''

# %%
def results_cleaner(table: list) -> pd.DataFrame:
    """This cleans the data of the scraped by selenium. Creates a list with proper results names in it.
       Don't know if I will be using all the columns that I've made here. But its better to make many
       different columns than going back here to update my code.

    Args:
        table (list): The table ouput by result_scraper_selenium

    Returns:
        pd.DataFrame: A dataframe -> cleaned data for the results.
    """
    detailed_result_selenium = []
    general_result_selenium = []
    result_as_int_selenium = []
    
    for per_row in table:
        if per_row == "background: rgb(171, 235, 198);":
            detailed_result_selenium.append("1st Try Success")
            general_result_selenium.append("Success")
            result_as_int_selenium.append("1")
            continue
        if per_row == "background: rgb(174, 214, 241);":
            detailed_result_selenium.append("2nd Try Success")
            general_result_selenium.append("Success")
            result_as_int_selenium.append("2")
            continue
        if per_row == "background: rgb(230, 176, 170);":
            detailed_result_selenium.append("3rd Try Success")
            general_result_selenium.append("Success")
            result_as_int_selenium.append("3")
            continue
        if per_row == "background: rgb(210, 180, 222);":
            detailed_result_selenium.append("Failed")
            general_result_selenium.append("Failed")
            result_as_int_selenium.append("0")
            continue

    df_results = pd.DataFrame()
    df_results["Detailed Result"] = detailed_result_selenium
    df_results["General Result"] = general_result_selenium
    df_results["Result as Number"] = result_as_int_selenium
    
    return df_results

# %% [markdown]
# ### Running the new function:

# %%
df_results = results_cleaner(data_table_selenium)

# %%
df_results
# Out:
#      Detailed Result General Result Result as Number
# 0    2nd Try Success        Success                2
# 1    3rd Try Success        Success                3
# 2    3rd Try Success        Success                3
# 3    3rd Try Success        Success                3
# 4    2nd Try Success        Success                2
# ..               ...            ...              ...
# 593  2nd Try Success        Success                2
# 594  1st Try Success        Success                1
# 595  2nd Try Success        Success                2
# 596           Failed         Failed                0
# 597  1st Try Success        Success                1
#
# [598 rows x 3 columns]

# %% [markdown]
# ### We can see that it is a success. Will be saving this as CSV File:

# %%
df_results.to_csv("../data/cleaned/cleaned_result.csv", index=False)

# %% [markdown]
# ## Now, its time to scrape the tables using Pandas:

# %%
all_tables_pandas = pd.read_html(page_url)
# Throwing the first one since its a table that is not needed.
selected_tables = all_tables_pandas[1:].copy()

# %%
# Looking at the "selected_tables":
selected_tables
# Out:
# [     Ep.     Air Date                              Featured Market  \
#  0      1      April 7                   Namgwangju Market, Gwangju
#  1      1      April 7                   Namgwangju Market, Gwangju
#  2      1      April 7                   Namgwangju Market, Gwangju
#  3      2     April 14                         Seomun Market, Daegu
#  4      2     April 14                         Seomun Market, Daegu
#  ..   ...          ...                                          ...
#  112   38  December 22      Gangneung Traditional Market, Gangneung
#  113   38  December 22      Gangneung Traditional Market, Gangneung
#  114   39  December 29  Gwangmyeong Traditional Market, Gwangmyeong
#  115   39  December 29  Gwangmyeong Traditional Market, Gwangmyeong
#  116   39  December 29  Gwangmyeong Traditional Market, Gwangmyeong
#
#                 Dressing Theme Concept Song Questions[b] + Snack Time Game[c]  \
#  0                  Market Stall Owner                              BTS - DNA
#  1                  Market Stall Owner                Bolbbalgan4 - Fight Day
#  2                  Market Stall Owner                  Seventeen - Very Nice
#  3                  Market Stall Owner                         Chakra - Hey U
#  4                  Market Stall Owner     Girls' Generation-TTS - Adrenaline
#  ..                                ...                                    ...
#  112                 Amazing Christmas              New/Old OST Quiz (Dramas)
#  113                 Amazing Christmas                 Wanna One - Flowerbomb
#  114  2018 DoReMi Entertainment Awards              Sechs Kies - Road Fighter
#  115  2018 DoReMi Entertainment Awards               New / Old Neologism Quiz
#  116  2018 DoReMi Entertainment Awards                       K/DA - Pop/Stars
#
#                                         Guest(s)
#  0                                             —
#  1                                             —
#  2                                             —
#  3                                             —
#  4                                             —
#  ..                                          ...
#  112  Hyoyeon (Girls' Generation), Doyoung (NCT)
#  113  Hyoyeon (Girls' Generation), Doyoung (NCT)
#  114       Winner (Song Min-ho, Kang Seung-yoon)
#  115       Winner (Song Min-ho, Kang Seung-yoon)
#  116       Winner (Song Min-ho, Kang Seung-yoon)
#
#  [117 rows x 6 columns],
#      Ep.     Air Date                          Featured Market  \
#  0    40    January 5  Hongseong Traditional Market, Hongseong
#  1    40    January 5  Hongseong Traditional Market, Hongseong
#  2    40    January 5  Hongseong Traditional Market, Hongseong
#  3    41   January 12      Gochang Traditional Market, Gochang
#  4    41   January 12      Gochang Traditional Market, Gochang
#  ..   ..          ...                                      ...
#  147  88  December 21            Guri Traditional Market, Guri
#  148  88  December 21            Guri Traditional Market, Guri
#  149  89  December 28            Noryangjin Fish Market, Seoul
#  150  89  December 28            Noryangjin Fish Market, Seoul
#  151  89  December 28            Noryangjin Fish Market, Seoul
#
#                              Dressing Theme Concept  \
#  0                      Muddling Palace Grand Feast
#  1                      Muddling Palace Grand Feast
#  2                      Muddling Palace Grand Feast
#  3    Cosmic Turmoil Attack with Speed and Velocity
#  4    Cosmic Turmoil Attack with Speed and Velocity
#  ..                                             ...
#  147                                Merry Christmas
#  148                                Merry Christmas
#  149            The 2nd DoReMi Entertainment Awards
#  150            The 2nd DoReMi Entertainment Awards
#  151            The 2nd DoReMi Entertainment Awards
#
#      Song Questions[b] + Snack Time Game[c]                           Guest(s)
#  0                               BTS - Dope          Lee Se-young, Yeo Jin-goo
#  1              Voice Support Quiz (Dramas)          Lee Se-young, Yeo Jin-goo
#  2        Kim Johan - Love Prepared For You          Lee Se-young, Yeo Jin-goo
#  3     Kan Mi-youn (feat. Eric) - Paparazzi               WJSN (Luda, Dayoung)
#  4                      Lyrics Reading Quiz               WJSN (Luda, Dayoung)
#  ..                                     ...                                ...
#  147                           Dialect Tour          Lee Si-eon, Simon Dominic
#  148         Ailee - Mind Your Own Business          Lee Si-eon, Simon Dominic
#  149                          IU - Blueming  Hong Seok-cheon, Rosé (Blackpink)
#  150         Choreography Décalcomanie Quiz  Hong Seok-cheon, Rosé (Blackpink)
#  151                      VIXX - Chained Up  Hong Seok-cheon, Rosé (Blackpink)
#
#  [152 rows x 6 columns],
#           Ep.     Air Date                         Featured Market  \
#  0         90    January 4  Yeonggwang Terminal Market, Yeonggwang
#  1         90    January 4  Yeonggwang Terminal Market, Yeonggwang
#  2         90    January 4  Yeonggwang Terminal Market, Yeonggwang
#  3         91   January 11           Baran Mansae Market, Hwaseong
#  4         91   January 11           Baran Mansae Market, Hwaseong
#  ..       ...          ...                                     ...
#  150  139 [t]  December 19    Incheon Complex Fish Market, Incheon
#  151  139 [t]  December 19    Incheon Complex Fish Market, Incheon
#  152  140 [u]  December 26                  Bukbu Market, Cheongju
#  153  140 [u]  December 26                  Bukbu Market, Cheongju
#  154  140 [u]  December 26                  Bukbu Market, Cheongju
#
#             Dressing Theme Concept  \
#  0    2020 Geng-Zi Year Let's Play
#  1    2020 Geng-Zi Year Let's Play
#  2    2020 Geng-Zi Year Let's Play
#  3          DoReMi In The SF Movie
#  4          DoReMi In The SF Movie
#  ..                            ...
#  150                     Christmas
#  151                     Christmas
#  152                 DoReMi Awards
#  153                 DoReMi Awards
#  154                 DoReMi Awards
#
#            Song Questions[b] + Snack Time Game[c]  \
#  0                                  Mamamoo - Hip
#  1                      Relation Between The Two?
#  2                            Seomoon Tak - Chain
#  3                       Girls' Generation - Echo
#  4                  I Can See Your Title (Dramas)
#  ..                                           ...
#  150                         Guess The Debut Song
#  151  Giriboy (feat. The Quiett, Bewhy) - Skyblue
#  152                    Wonder Girls - I Feel You
#  153                                 Dialect Tour
#  154    Sunny Hill - Princess and Prince Charming
#
#                              Guest(s)
#  0                        Kim Won-hee
#  1                        Kim Won-hee
#  2                        Kim Won-hee
#  3              SF9 (Inseong, Rowoon)
#  4              SF9 (Inseong, Rowoon)
#  ..                               ...
#  150  Don Mills, Song Min-ho (Winner)
#  151  Don Mills, Song Min-ho (Winner)
#  152               Kim Seon-ho, Heize
#  153               Kim Seon-ho, Heize
#  154               Kim Seon-ho, Heize
#
#  [155 rows x 6 columns],
#       Ep.     Air Date                        Featured Market  \
#  0    141    January 2     Seongdae Traditional Market, Seoul
#  1    141    January 2     Seongdae Traditional Market, Seoul
#  2    141    January 2     Seongdae Traditional Market, Seoul
#  3    142    January 9                    Yaksu Market, Seoul
#  4    142    January 9                    Yaksu Market, Seoul
#  ..   ...          ...                                    ...
#  149  191  December 18     Gocheok Neighborhood Market, Seoul
#  150  191  December 18     Gocheok Neighborhood Market, Seoul
#  151  192  December 25  Dongsong Traditional Market, Cheorwon
#  152  192  December 25  Dongsong Traditional Market, Cheorwon
#  153  192  December 25  Dongsong Traditional Market, Cheorwon
#
#        Dressing Theme Concept Song Questions[b] + Snack Time Game[c]  \
#  0         The Century's Duos                  Lexa - Love Valentine
#  1         The Century's Duos           Find The Source of This Meme
#  2         The Century's Duos            BtoB - All Wolves Except Me
#  3    Short-lived Resolutions                     Nine Muses - Drama
#  4    Short-lived Resolutions         Choreography Décalcomanie Quiz
#  ..                       ...                                    ...
#  149                Won't Die                 New/Old Neologism Quiz
#  150                Won't Die                             EXID - DDD
#  151          Ghost Christmas                     Turbo - White Love
#  152          Ghost Christmas           Find The Source of This Meme
#  153          Ghost Christmas                        Apink - It Girl
#
#                                     Guest(s)
#  0                   Nam Chang-hee, Jo Se-ho
#  1                   Nam Chang-hee, Jo Se-ho
#  2                   Nam Chang-hee, Jo Se-ho
#  3    Weki Meki (Choi Yoo-jung, Kim Do-yeon)
#  4    Weki Meki (Choi Yoo-jung, Kim Do-yeon)
#  ..                                      ...
#  149           Lee Jin-wook, Gong Seung-yeon
#  150           Lee Jin-wook, Gong Seung-yeon
#  151                           Rain, Kim Bum
#  152                           Rain, Kim Bum
#  153                           Rain, Kim Bum
#
#  [154 rows x 6 columns],
#       Ep.     Air Date                         Featured Market  \
#  0    193    January 1                    Ahyeon Market, Seoul
#  1    193    January 1                    Ahyeon Market, Seoul
#  2    193    January 1                    Ahyeon Market, Seoul
#  3    194    January 8         Dongulsan Complex Market, Ulsan
#  4    194    January 8         Dongulsan Complex Market, Ulsan
#  ..   ...          ...                                     ...
#  148  243  December 24  Yeongdeungpo Traditional Market, Seoul
#  149  243  December 24  Yeongdeungpo Traditional Market, Seoul
#  150  243  December 24  Yeongdeungpo Traditional Market, Seoul
#  151  244  December 31                  Wongogae Market, Daegu
#  152  244  December 31                  Wongogae Market, Daegu
#
#                          Dressing Theme Concept  \
#  0                       Got To Catch This Year
#  1                       Got To Catch This Year
#  2                       Got To Catch This Year
#  3                             You're My Manito
#  4                             You're My Manito
#  ..                                         ...
#  148                         AS[d] on Christmas
#  149                         AS[d] on Christmas
#  150                         AS[d] on Christmas
#  151  Year-End Special - 2022, A Year Passes By
#  152  Year-End Special - 2022, A Year Passes By
#
#                  Song Questions[b] + Snack Time Game[c]  \
#  0                      Goofy - Everything Will Be Fine
#  1                 Doppelganger Quiz (Actors/Actresses)
#  2                OLNL (feat. Yunhway, Giriboy) - ZERO%
#  3        Sistar (feat. Giriboy) - Don't Be Such A Baby
#  4                     Consonants Quiz (Ramyeon Brands)
#  ..                                                 ...
#  148                        Stray Kids - Christmas EveL
#  149                       Noraebang Accompaniment Quiz
#  150                                Younha - Oort Cloud
#  151                        BTS - Airplane pt.2[ba][bb]
#  152  Lyrics in the Square Quiz Consonants Quiz (200...
#
#                           Guest(s)
#  0    Cho Jin-woong, Choi Woo-shik
#  1    Cho Jin-woong, Choi Woo-shik
#  2    Cho Jin-woong, Choi Woo-shik
#  3                      Haha, Byul
#  4                      Haha, Byul
#  ..                            ...
#  148      Kim Tae-woo (g.o.d), Tei
#  149      Kim Tae-woo (g.o.d), Tei
#  150      Kim Tae-woo (g.o.d), Tei
#  151                      (G)I-dle
#  152                      (G)I-dle
#
#  [153 rows x 6 columns],
#            Ep.     Air Date                     Featured Market  \
#  0    245 [bc]    January 7                Singok Market, Seoul
#  1    245 [bc]    January 7                Singok Market, Seoul
#  2         246   January 14     Namhansanseong Market, Seongnam
#  3         246   January 14     Namhansanseong Market, Seongnam
#  4         246   January 14     Namhansanseong Market, Seongnam
#  ..        ...          ...                                 ...
#  146       295  December 23  Saemaeul Traditional Market, Seoul
#  147       295  December 23  Saemaeul Traditional Market, Seoul
#  148       296  December 30              Heukseok Market, Seoul
#  149       296  December 30              Heukseok Market, Seoul
#  150       296  December 30              Heukseok Market, Seoul
#
#                                  Dressing Theme Concept  \
#  0    New Year Special - 2023, Let's Laugh in the Ne...
#  35                                  TBA - TBA[bp][bq]
#  36                                                TBA
#
#                                               Guest(s)
#  0   Brian Joo (Fly to the Sky), Kyuhyun (Super Jun...
#  1   Brian Joo (Fly to the Sky), Kyuhyun (Super Jun...
#  2   Brian Joo (Fly to the Sky), Kyuhyun (Super Jun...
#  3                          Lee Dong-wook, Kim Hye-jun
#  4                          Lee Dong-wook, Kim Hye-jun
#  5                          Lee Dong-wook, Kim Hye-jun
#  6                         Kim Seo-hyung, Lee Hyun-woo
#  7                         Kim Seo-hyung, Lee Hyun-woo
#  8                         Kim Seo-hyung, Lee Hyun-woo
#  9                                                   —
#  10                                                  —
#  11                            Lee Ho-cheol, Na Sun-uk
#  12                            Lee Ho-cheol, Na Sun-uk
#  13                            Lee Ho-cheol, Na Sun-uk
#  14                          Park Min-young, Na In-woo
#  15                          Park Min-young, Na In-woo
#  16                          Park Min-young, Na In-woo
#  17          Le Sserafim (Kim Chae-won, Hong Eun-chae)
#  18          Le Sserafim (Kim Chae-won, Hong Eun-chae)
#  19          Le Sserafim (Kim Chae-won, Hong Eun-chae)
#  20                  Kim Bum-soo, Seo Eun-kwang (BtoB)
#  21                  Kim Bum-soo, Seo Eun-kwang (BtoB)
#  22                  Kim Bum-soo, Seo Eun-kwang (BtoB)
#  23                                      Chungha, Bibi
#  24                                      Chungha, Bibi
#  25                                      Chungha, Bibi
#  26                                  Swings, Jung Hyuk
#  27                                  Swings, Jung Hyuk
#  28                                  Swings, Jung Hyuk
#  29                         Kim Ji-won, Kwak Dong-yeon
#  30                         Kim Ji-won, Kwak Dong-yeon
#  31                         Kim Ji-won, Kwak Dong-yeon
#  32                                 Ha Do-kwon, K.Will
#  33                                 Ha Do-kwon, K.Will
#  34                                 Ha Do-kwon, K.Will
#  35  Jo Hye-ryun, Haha, Bbaek Ga (Koyote), Eunhyuk ...
#  36  Jo Hye-ryun, Haha, Bbaek Ga (Koyote), Eunhyuk ...  ]

# %% [markdown]
# ### We can see that it perfectly scrapes the data in each table that is needed.
# ### Declaring multiple functions that will be used to semi-clean the data gathered using Pandas:

# %%
def string_formatter(text: str) -> str:
    """This removes the "Notes" / "HyperLink" in the text

    Args:
        text (str): Any text in the table. 

    Returns:
        str: Formatted string.
    """
    pattern = r"\[[a-z]{1,2}\]"
    
    handler = re.findall(pattern, text)
    if handler:
        text_list = list(text)
        filtered_list = []
        for per_char in text_list:
            if per_char == "[":
                break
            else:
                filtered_list.append(per_char)
        filtered_text = "".join(filtered_list).strip()
        return filtered_text
    else:
        return text

def month_extractor(text: str) -> str:
    """This function just retrieves the Date in the "Air Date" column. Might be useful
    in the data visualization.

    Args:
        text (str): Text in the "Air Date" column.

    Returns:
        str: Month in String format. To be inserted in the new column named "Month".
    """
    text_list = list(text)
    handler = []
    
    for per_char in text_list:
        if per_char.isalpha():
            handler.append(per_char)
    
    month = "".join(handler).strip()
    return month

def tables_scraper_pandas(table: list[pd.DataFrame]) -> pd.DataFrame:
    """After the pandas scraped the tables, this function will add two new columns
       that might be useful for the next step -> "Month" and "Year"
       This function also formats the texts by calling to another functions.

    Args:
        table (list[pd.DataFrame]): Dataframe consisting of tables scraped by Pandas.

    Returns:
        pd.DataFrame: Returns a semi-cleaned data. Will still output as RAW data.
    """
    consolidated_tables_pandas = pd.DataFrame()
    consolidated_tables_pandas["Year"] = [] # Adding two new column that might be useful for the next steps.
    consolidated_tables_pandas["Month"] = []

    year = 2018
    # Iterating through each table:
    for per_table in table:
        cleaned_table = []
        # Iterating through each row of the table. Applying the two functions above to this function.
        for _, row in per_table.iterrows():
            current_row = row.copy()
            
            current_episode = str(current_row["Ep."])
            filtered_episode = string_formatter(current_episode)
            current_row["Ep."] = filtered_episode
            
            current_date = str(current_row["Air Date"])
            filtered_date = string_formatter(current_date)
            current_row["Air Date"] = f"{filtered_date}, {year}"
            
            month = month_extractor(filtered_date)
            current_row["Month"] = month
            
            current_row["Year"] = str(year)
            
            current_song = str(current_row["Song Questions[b] + Snack Time Game[c]"])
            filtered_song = string_formatter(current_song)
            current_row["Song Questions[b] + Snack Time Game[c]"] = filtered_song
            
            cleaned_table.append(current_row.to_dict())
        year += 1
        cleaned_df = pd.DataFrame(cleaned_table)
        consolidated_tables_pandas = pd.concat([consolidated_tables_pandas, cleaned_df], axis=0)

    consolidated_tables_pandas = consolidated_tables_pandas.drop(
        ["Featured Market", "Dressing Theme Concept", "Guest(s)"], axis=1
        ).rename(
            columns={"Ep." : "Episode #", "Song Questions[b] + Snack Time Game[c]" : "Song Questions + Snack Time Game"}
            )

    columns_inorder = ["Episode #", "Song Questions + Snack Time Game", "Air Date", "Month", "Year"]
    df_arranged_columns = consolidated_tables_pandas[columns_inorder].copy()
    return df_arranged_columns

# %%
# Calling the function to get the dataframe with formatted texts and with two new columns.

df_tables_pandas = tables_scraper_pandas(selected_tables)

# %%
df_tables_pandas
# Out:
#    Episode #               Song Questions + Snack Time Game        Air Date  \
# 0          1                                      BTS - DNA   April 7, 2018
# 1          1                        Bolbbalgan4 - Fight Day   April 7, 2018
# 2          1                          Seventeen - Very Nice   April 7, 2018
# 3          2                                 Chakra - Hey U  April 14, 2018
# 4          2             Girls' Generation-TTS - Adrenaline  April 14, 2018
# ..       ...                                            ...             ...
# 32       308                         JuJu Club - Essay Love  March 30, 2024
# 33       308                           If It's the End Quiz  March 30, 2024
# 34       308  Beenzino (feat. Cautious Clay) - Travel Again  March 30, 2024
# 35       309                                      TBA - TBA   April 6, 2024
# 36       309                                            TBA   April 6, 2024
#
#     Month  Year
# 0   April  2018
# 1   April  2018
# 2   April  2018
# 3   April  2018
# 4   April  2018
# ..    ...   ...
# 32  March  2024
# 33  March  2024
# 34  March  2024
# 35  April  2024
# 36  April  2024
#
# [919 rows x 5 columns]

# %% [markdown]
# ### We can see that this data has more rows than the Result dataframe. That is because this data has the "Snack Quiz Game" data in it per episode. Other than that, there's also episodes wherein the Round 1 or Round 2 has no Result in it since its not being played as a whole team but rather by multiple teams.
# ### I'm gonna clean this up in the next step. For now, this will be saved as a raw data:

# %%
df_tables_pandas.to_csv("../data/raw/raw_tables.csv", index=False)

# %% [markdown]
# ## To the next step -> "data_cleaning_merging.ipynb"
